# %%
# %matplotlib notebook
import matplotlib as mp
#matplotlib.use('nbagg')
import numpy as np
from matplotlib import pyplot as plt
import pylab as pyl

#plt.rcParams["figure.figsize"] =(3,4)

# %%
a = np.arange(4)
a
# Out:
# array([0, 1, 2, 3])

# %%
print (a)
# Out:
# [0 1 2 3]

# %%
plt.interactive (True)

# %%
u721 = np.loadtxt("/Volumes/NO NAME/WaveData721.csv",skiprows=3,delimiter =',')
plt.figure(1)
plt.clf()
fx2 =np.arange(2001)
fx2 = fx2*0.5/5E-6/2000

plt.subplot(3,2,1)
plt.plot(u721[0:4000,1])
plt.subplot(3,2,3)
plt.plot(fx2,abs(pyl.rfft(u721[0:4000,1])))
plt.subplot(3,2,5)
plt.plot(fx2,abs(pyl.rfft(u721[0:4000,1])))
plt.subplot(3,2,2)
plt.plot(u721[0:4000,1]**2)
plt.subplot(3,2,4)
plt.plot(fx2,abs(pyl.rfft(u721[0:4000,1]**2)))
plt.subplot(3,2,6)
plt.plot(fx2,abs(pyl.rfft(u721[0:4000,1]**2)))
#show()

# %%
import plotly.plotly as py
import plotly.graph_objs as go

# Create random data with numpy
import numpy as np

N = 500
random_x = np.linspace(0, 1, N)
random_y = np.random.randn(N)

# Create a trace
trace = go.Scatter(
    x = random_x,
    y = random_y
)

data = [trace]

py.iplot(data, filename='basic-line')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-21-399e0a523259> in <module>()
#       1
# ----> 2 import plotly.plotly as py
#       3 import plotly.graph_objs as go
#       4
#       5 # Create random data with numpy
#
# ModuleNotFoundError: No module named 'plotly'

# %%
import matplotlib.pyplot as plt
from ipywidgets import interact

def f(n):
    plt.plot([0,1,2],[0,1,n])
   # plt.show()
interact(f,n=(0,10))

# %%
quickref

# %%
from ipywidgets.widgets.interaction import interact
import ipywidgets.widgets as widgets
def plotsin(f, ln):
    x = np.linspace(-10,10, 2**10)
    s = np.sin(f*x)
    ax.lines[0].set_data(x, s)


fig, ax = plt.subplots(1,1)
ln = ax.plot([], [], label='sin')
ax.set_xlim(-10, 10)
ax.set_ylim(-1, 1)
def plot_interactive2():
    def pls2(f):
        plotsin(f, ln)
    ww = widgets.FloatSlider(description='frequency', min=1, max=100)
    interact(pls2, f=ww)
# Out:
# <div id='3127aac1-ccd1-472b-ac0f-571c33fd3c9b'></div>

# %%
plot_interactive2()
# Out:
# A Jupyter Widget

# %%
plt.savefig('sample2.pdf')

# %%
import seaborn as sns
sns.set_palette("husl")

# %%
def sinplot(flip=1):
    x = np.linspace(0, 14, 100)
    for i in range(1, 7):
        plt.plot(x, np.sin(x + i * .5) * (7 - i) * flip)

# %%
plt.figure()
sinplot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
sns.palplot(sns.color_palette("cubehelix", 8))
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
sns.set_palette("cubehelix")

# %%
plt.figure()
sinplot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
sns.palplot(sns.cubehelix_palette(8, start=.5, rot=-.75))
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
cmap = sns.cubehelix_palette(8, start=.5, rot=-.75)

# %%
cmap
# Out:
# [[0.8423298817793848, 0.8737404427964184, 0.7524954030731037],
#  [0.6825187635707243, 0.810691907283208, 0.6352470180118206],
#  [0.5109365778646006, 0.7367198696575319, 0.5730408794126332],
#  [0.3720866446574984, 0.6378633419526029, 0.5550368905837924],
#  [0.2884627663592704, 0.5163814459748142, 0.5434217716422115],
#  [0.24670155725826665, 0.37340824813905654, 0.49725690696587516],
#  [0.2217962654723154, 0.23841378594571613, 0.39797674055755683],
#  [0.17250549177124488, 0.11951843162770594, 0.24320155229883056]]

# %%
def sinplotcmap(cmap=None,flip=1):
    x = np.linspace(0, 14, 100)
    for i in range(1, 7):
        plt.plot(x, np.sin(x + i * .5) * (7 - i) * flip,color=cmap[i])

# %%
plt.figure()
sinplotcmap(cmap=cmap)
# Out:
# <div id='ecb73735-a501-4bde-8d55-ab3d3519250b'></div>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-3f4db5f41d99> in <module>()
#       1 plt.figure()
# ----> 2 sinplotcmap(cmap=cmap)
#
# <ipython-input-34-5032848533af> in sinplotcmap(cmap, flip)
#       2     x = np.linspace(0, 14, 100)
#       3     for i in range(1, 7):
# ----> 4         plt.plot(x, np.sin(x + i * .5) * (7 - i) * flip,cmap[i])
#       5
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    3315                       mplDeprecation)
#    3316     try:
# -> 3317         ret = ax.plot(*args, **kwargs)
#    3318     finally:
#    3319         ax._hold = washold
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1896                     warnings.warn(msg % (label_namer, func.__name__),
# ...

# %%
# ?plt.plot
